# %%
import numpy as np


weights=np.load("./data/weights.npy",allow_pickle=True)

# %%
for i in range(len(weights)):
    print(weights[i].shape)
# Out:
# (4, 100)
# (100, 100)
# (100,)
# (100, 1)
# (1,)

# %%
import matplotlib.pyplot as plt
plt.imshow(weights[0])
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.imshow(weights[1])

# %%
import tensorflow as tf

# %%
m=tf.constant([[1.,2,3],[4,5,6],[7,8,9]])
y=tf.constant([1.,2,3])

# %%
y+tf.random.normal((1,),0.,0.3)
# Out:
# <tf.Tensor: shape=(3,), dtype=float32, numpy=array([0.87002504, 1.870025  , 2.8700252 ], dtype=float32)>

# %%
tf.matmul(m,tf.transpose([y]))
# Out:
# <tf.Tensor: shape=(3, 1), dtype=int32, numpy=
# array([[14],
#        [32],
#        [50]], dtype=int32)>
